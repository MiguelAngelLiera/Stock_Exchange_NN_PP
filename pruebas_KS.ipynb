# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ks_2samp

m1 = 'DWT_GRU'
m2 = 'NARNN'
DWT_NARNN = np.load(f'distribuciones/ACTINVRB/{m1}.npy')
NARNN = np.load(f'distribuciones/ACTINVRB/{m2}.npy')

ts_ks_statistic, ts_ks_p_value = ks_2samp(DWT_NARNN, NARNN)
os_ks_statistic, os_ks_p_value = ks_2samp(DWT_NARNN, NARNN,'greater')

plt.title(f'Distribución de errores entre {m1} y {m2}')
plt.text(0.75, 0.1, f"KS: {round(ts_ks_statistic,4)}, Valor p: {round(ts_ks_p_value,18)}", fontsize=12, ha='center', va='center', transform=plt.gca().transAxes)
plt.text(0.75, 0.05, f"KS: {round(os_ks_statistic,4)}, Valor p: {round(os_ks_p_value,18)}", fontsize=12, ha='center', va='center', transform=plt.gca().transAxes)

plt.plot(DWT_NARNN, color = '#451952', label = f'{m1}') #Señal original
plt.plot(NARNN, color='#AE445A', label = f'{m2}') #Señal predicha

plt.legend()
plt.show()

if ts_ks_p_value < 0.05:
    print("Se rechaza la hipotesis nula y se acepta la alternativa: \n Los errores no comparten la misma distribución, existe una diferencia estadísticamente significativa")
else:
    print("Se acepta la hipotesis nula \n Los errores comparten la misma distribución, no existe una diferencia estadísticamente significativa")

if os_ks_p_value < 0.05:
    print(f"Se rechaza la hipotesis nula y se acepta la alternativa: \n el modelo {m1} reporta un menor error estocastico")
else:
    print(f"Se acepta la hipotesis nula \n el modelo {m2} reporta un menor error estocastico")
# Out:
# Se rechaza la hipotesis nula y se acepta la alternativa:
#  Los errores no comparten la misma distribución, existe una diferencia estadísticamente significativa
# Se rechaza la hipotesis nula y se acepta la alternativa:
#  el modelo DWT_NARNN reporta un menor error estocastico

# %%
from src.pruebas.kolmogorov import prueba_KS

# %%
m1 = 'DWT_NARNN'
m2 = 'NARNN'
modo = 'greater'

prueba_KS(m1,m2,modo)
# Out:
# Se rechaza la hipotesis nula y se acepta la alternativa:
#  Los errores no comparten la misma distribución, existe una diferencia estadísticamente significativa
# Se acepta la hipotesis nula
#  el modelo NARNN reporta un menor error estocastico

# %%
m1 = 'DWT_LSTM'
m2 = 'LSTM'
modo = 'greater'

prueba_KS(m1,m2,modo)
# Out:
# Se acepta la hipotesis nula
#  Los errores comparten la misma distribución, no existe una diferencia estadísticamente significativa
# Se acepta la hipotesis nula
#  el modelo LSTM reporta un menor error estocastico

# %%
m1 = 'DWT_GRU'
m2 = 'GRU'
modo = 'greater'

prueba_KS(m1,m2,modo)
# Out:
# Se rechaza la hipotesis nula y se acepta la alternativa:
#  Los errores no comparten la misma distribución, existe una diferencia estadísticamente significativa
# Se rechaza la hipotesis nula y se acepta la alternativa:
#  el modelo DWT_GRU reporta un menor error estocastico

# %%
m1 = 'NARNN'
m2 = 'DWT_LSTM'
modo = 'greater'

prueba_KS(m1,m2,modo)
# Out:
# Se rechaza la hipotesis nula y se acepta la alternativa:
#  Los errores no comparten la misma distribución, existe una diferencia estadísticamente significativa
# Se acepta la hipotesis nula
#  el modelo DWT_LSTM reporta un menor error estocastico

# %%
m1 = 'NARNN'
m2 = 'DWT_GRU'
modo = 'greater'

prueba_KS(m1,m2,modo)
# Out:
# Se acepta la hipotesis nula
#  Los errores comparten la misma distribución, no existe una diferencia estadísticamente significativa
# Se acepta la hipotesis nula
#  el modelo DWT_GRU reporta un menor error estocastico

# %%
m1 = 'DWT_GRU'
m2 = 'DWT_LSTM'
modo = 'greater'

prueba_KS(m1,m2,modo)
# Out:
# Se acepta la hipotesis nula
#  Los errores comparten la misma distribución, no existe una diferencia estadísticamente significativa
# Se acepta la hipotesis nula
#  el modelo DWT_LSTM reporta un menor error estocastico
